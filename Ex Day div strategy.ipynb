# %%
import pandas as pd
#pd.core.common.is_list_like = pd.api.types.is_list_like
#from iexfinance import get_historical_data as hist
#from iexfinance import Stock as stock
import requests
from datetime import datetime,timedelta
import matplotlib.pyplot as plt
import csv
iex = "https://api.iextrading.com/1.0"
#outfile = open("returns.csv",'w',newline='')
#returns = pd.DataFrame()
#returns = outfile


#returns = list()
#one_day = timedelta(days=1)

# %%
infile = open("listdividend-stocks2.csv",'r')
divstocks = pd.read_csv(infile,names = ['Symbol'])
#divstocks = Series(divstocks)
infile.close()
#divstocks = infile.read()    
#divstocks = csv.reader(infile)

# %%
def FigReturns(stocks):
    outfile = open("returns.csv",'w',newline='')
    returns = csv.writer(outfile)
    for stock in stocks['Symbol']:
        #stock = str(stock)
        print (stock)
        a = requests.get("https://api.iextrading.com/1.0/stock/" + stock + "/chart/5y")
        b = requests.get("https://api.iextrading.com/1.0/stock/" + stock + "/dividends/5y")
        prices = pd.read_json(a.text)
        divs = pd.read_json(b.text)
        divs.exDate = pd.to_datetime(divs.exDate)
        divprice = pd.merge(divs,prices,left_on= "exDate",right_on= ("date"))
        meanreturn = divprice.close.mean() - divprice.open.mean()
        
        returns.writerow((stock,meanreturn))
        
        
    #returns.to_csv("returns.csv")
    
    outfile.close()

# %%
#twostocks = ['IRL','O',]

# %%
FigReturns(divstocks)
# Out:
# CHFN
# SPAR
# ZION
# IOSP
# NKSH
# TIPT
# JKHY
# MTEX
# DHXM
# DRYS
# BPOP
# EMCI
# LOB
# QCOM

# %%
for stock in divstocks['Symbol']:
    print(stock)
# Out:
# CHFN
# SPAR
# ZION
# IOSP
# NKSH
# TIPT
# JKHY
# MTEX
# DHXM
# DRYS
# BPOP
# EMCI
# LOB
# QCOM
# UG
# ISCA
# AMNB
# ANAT
# BRKS
# CATY
# CHFC
# CHRW
# CTWS
# EXPD
# FBNK
# FMBH
# FNCB
# FRME
# ILG
# LCNB
# NAVI
# ONB
# PEP
# SAFT
# SLGN
# SSNC
# TRST
# UFPI
# WEN
# ZEUS
# BRKR
# EDUC
# EMCF
# PEBK
# PFG
# STBZ
# WING
# CASS
# CSGS
# CTRN
# EGOV
# HWC
# PWOD
# RMCF
# AVT
# LRCX
# ODFL
# PAHC
# REIS
# TIVO
# UVSP
# WEBK
# ESCA
# NRIM
# PCH
# PTEN
# AAON
# ACET
# ADP
# AMSF
# AUBN
# BOTJ
# CBFV
# CBSH
# CME
# DNBF
# ESBK
# EXPO
# FDUS
# FFNW
# FMNB
# FUSB
# GARS
# GBDC
# ICBK
# ICFI
# KEQU
# KFRC
# LANC
# MANT
# MBWM
# MFSF
# NTRS
# OTEX
# SVBI
# UBCP
# UBSI
# WSBC
# CASH
# CCBG
# DAKT
# FFIC
# JRVR
# RICK
# TFSL
# UMBF
# ROST
# SHOO
# STFC
# ARII
# FORR
# TXRH
# FISI
# GLNG
# GOGL
# JJSF
# ROIC
# SEIC
# ALOT
# ATRI
# BBBY
# CARO
# CFFI
# CIZN
# CMCT
# CMFN
# CNMD
# CRWS
# CSFL
# CTBI
# EFSC
# ESND
# ESSA
# FBSS
# FCAP
# FFIN
# FLXS
# GILD
# GLPI
# HOFT
# HWBK
# IIIN
# ITIC
# JCS
# LAMR
# MBFI
# AFIN
# ARCB
# BRKL
# BSET
# CMCO
# FCCY
# FIBK
# FRBA
# GABC
# HSII
# HTBK
# HTLF
# ISBC
# NBN
# NXST
# SBFG
# SFBC
# SIRI
# TILE
# TRCB
# TSBK
# VIVO
# WAFD
# WSFS
# YLCO
# AAPL
# ARTNA
# ASTE
# BJRI
# BOKF
# CCD
# CG
# CGO
# CHI
# CHW
# CHY
# CSQ
# EBTC
# FCEF
# GROW
# LSTR
# MCEF
# MRLN
# NATI
# PKOH
# PZZA
# SCHN
# SONA
# UIHC
# VNOM
# WCFB
# WSTG
# WVFC
# CWBC
# HNDL
# MCBC
# PCAR
# POOL
# BFST
# CAKE
# EML
# GCBC
# HMTA
# HOMB
# KLAC
# LABL
# MINI
# MSEX
# OTTR
# PSMT
# SGC
# SHBI
# SIGI
# SMBC
# TAIT
# AMOT
# CDC
# CDL
# CEY
# CEZ
# CFA
# CFO
# CID
# CIL
# CIZ
# COLM
# CPSI
# CSA
# CSB
# CSF
# DRAD
# GWRS
# HNNA
# MGPI
# MSFT
# NCMI
# RILY
# SNLN
# TTEK
# VSDA
# VSMV
# WYNN
# XPER
# ALGT
# AMGN
# AMSWA
# BWFG
# CCOI
# CGNX
# CLCT
# EBMT
# FDEF
# HA
# HRZN
# IPHS
# KHC
# MSBI
# PCSB
# PNBK
# SAL
# SBRA
# SPOK
# SSB
# SSBI
# TECH
# ADES
# BGCP
# CLAR
# FDBC
# JACK
# JCOM
# NMRK
# PAAS
# PACW
# PFIN
# SYMC
# TACT
# WBA
# DWIN
# HEES
# KBWD
# KBWY
# KELYA
# KELYB
# LAND
# LDRI
# MCHP
# NDSN
# PEY
# PLW
# PROV
# VRIG
# WWD
# AGND
# AGZD
# CTSH
# DGRS
# DGRW
# EMCB
# EQIX
# FCAL
# FCVT
# FDIV
# FEMB
# FIXD
# FMB
# FMHI
# FTHI
# FTLB
# FTSL
# FTSM
# GLDI
# HYLS
# HYND
# HYZD
# LMAT
# LMBS
# MDIV
# PFLT
# POWL
# SLVO
# USOI
# AMAT
# CA
# CPTA
# EXPE
# FWRD
# HCAP
# LFUS
# MAR
# OXLC
# QYLD
# RECN
# RUTH
# SBSI
# SUNS
# BBSI
# CDW
# COHU
# CVON
# FLIR
# GBNK
# HCSG
# ODP
# SBT
# UCBA
# USLM
# DNKN
# FCBP
# FHB
# GPRE
# LYTS
# MKSI
# MNRO
# TSCO
# BLKB
# CORE
# CRAI
# HIHO
# KRNY
# OTTW
# WEYS
# ACNB
# MXIM
# NVDA
# SPKE
# ADI
# AGNC
# AROW
# BGFV
# BPR
# CBAN
# CBOE
# CCNE
# COST
# CSPI
# CSX
# EBIX
# FFBC
# FSFG
# GECC
# HAYN
# IBKR
# KINS
# KNSL
# MBCN
# MGEE
# MLAB
# MLHR
# MOFG
# MTGE
# MVBF
# NAVG
# NBTB
# NNBR
# OPOF
# PCB
# PFIS
# POWI
# PRGS
# PSEC
# RCKY
# SBGI
# SCHL
# SGA
# STRA
# TERP
# TRMK
# UBOH
# UFCS
# VIRT
# PBIP

# %%
b = requests.get("https://api.iextrading.com/1.0/stock/EMCF/dividends/5y")

# %%
b.text
returns
# Out:
# Empty DataFrame
# Columns: []
# Index: []
